# %%
# Rectangle
class Rectangle:
     def __init__(self, length, breadth):
          self.length = length
          self.breadth = breadth
          
     def __Area__(self):
          return '<{} {} >'.format(self.length, self.breadth)
     def area(self):
          self.area = (self.length * self.breadth)
          return self.area
     def perimeter(self):
          self.Perimeter = 2 * (self.length + self.breadth)
          return self.Perimeter
     
Ans = Rectangle(3, 4)
print("The length of rectangle is : ", 3)
print("The width of rectangle is : ", 4)
print('The area of rectanlge is :', Ans.area())
print('The Perimeter of rectangle is : ', Ans.perimeter())
# Out:
# The length of rectangle is :  3
# The width of rectangle is :  4
# The area of rectanlge is : 12
# The Perimeter of rectangle is :  14

# %%
# Bank Account
class BankAccount:
     def __init__(self, accountNumber, name, balance):
          self.accountNumber = accountNumber
          self.name = name
          self.balance = balance
          
     def deposit(self, amount):
          if amount > 0:
               self.balance += amount
               print(f'Deposit of {amount} successful.')
          else:
               print('Deposit amount must be greater than zero.')
               
     def withdrawal(self, amount):
          if 0 < amount <= self.balance:
               self.balance -= amount
               print(f'Withdrawal of {amount} successful.')
          else:
               print('Insufficient funds for withdrawal.')
               
     def bankFees(self):
          fee = self.balance * 0.05
          self.balance -= fee
          print(f'Bank fees of {fee} applied.')
          
     def display(self):
          print(f'Account Number : {self.accountNumber}')
          print(f'Account Holder Name : {self.name}')
          print(f'Account Balance : {self.balance}')
          
newAccount = BankAccount(2178514584, 'Mandy', 2800)
newAccount.withdrawal(700)
newAccount.deposit(1000)
newAccount.display()
newAccount.bankFees()
# Out:
# Withdrawal of 700 successful.
# Deposit of 1000 successful.
# Account Number : 2178514584
# Account Holder Name : Mandy
# Account Balance : 3100
# Bank fees of 155.0 applied.

# %%
class Computation:
    def __init__(self):
        pass

    def factorial(self, n):
        result = 1
        for i in range(1, n + 1):
            result *= i
        return result

    def natural_sum(self, n):
        return sum(range(1, n + 1))

    def test_prime(self, n):
        if n < 2:
            return False
        for i in range(2, int(n**0.5) + 1):
            if n % i == 0:
                return False
        return True

    def test_primes(self, a, b):
        return self.test_prime(a) and self.test_prime(b)

    def table_mult(self, n):
        for i in range(1, 11):
            print(f"{n} x {i} = {n*i}")

    @staticmethod
    def all_tables_mult():
        for i in range(1, 10):
            Computation().table_mult(i)

    @staticmethod
    def list_div(n):
        divisors = [i for i in range(1, n + 1) if n % i == 0]
        return divisors

    @staticmethod
    def list_div_prim(n):
        divisors = Computation.list_div(n)
        prime_divisors = [d for d in divisors if Computation().test_prime(d)]
        return prime_divisors


if __name__ == "__main__":
    computation = Computation()

    print(f"Factorial of 5: {computation.factorial(5)}")
    print(f"Sum of the first 5 integers: {computation.natural_sum(5)}")
    print(f"Is 7 prime? {computation.test_prime(7)}")
    print(f"Are 4 and 9 prime to each other? {computation.test_primes(4, 9)}")

    print("\nMultiplication Tables:")
    computation.table_mult(5)

    print("\nAll Multiplication Tables:")
    Computation.all_tables_mult()

    print("\nDivisors of 12:", computation.list_div(12))
    print("Prime Divisors of 12:", computation.list_div_prim(12))
# Out:
# Factorial of 5: 120
# Sum of the first 5 integers: 15
# Is 7 prime? True
# Are 4 and 9 prime to each other? False
#
# Multiplication Tables:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
#
# All Multiplication Tables:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90
#
# Divisors of 12: [1, 2, 3, 4, 6, 12]
# Prime Divisors of 12: [2, 3]

# %%
# Flash card
import random
class FlashCard:
     def __init__(self):
          self.__fruits = {
               'apple' : 'red',
               'banana' : 'yellow',
               'watermelon' : 'green',
               'strawberry' : 'pink',
               'guava' : 'green'
          }
          
     def quiz(self):
          while True:
               fruit ,color = random.choices(list(self.__fruits.items()))[0]
               print('What is the color of {}'.format(fruit))
               user_answer = input()
               if user_answer.lower() == color:
                    print('Sahi Jawab')
               else:
                    print('Galat Jawab')
                    
               option = int(input('Enter 0 to play again 1 to exit'))
               if option:
                    break
print('Welcome to the fruit quiz')
fc = FlashCard()
fc.quiz()
# Out:
# Welcome to the fruit quiz
# What is the color of banana
# Sahi Jawab
# What is the color of guava
# Sahi Jawab

# %%
import random 
d = {
     'apple' : 'red',
     'banana' : 'yellow',
     'watermelon' : 'green',
     'strawberry' : 'pink',
     'guava' : 'green'
     }
fruit , color = random.choices(list(d.items()))[0]
print(fruit)
print(color)
# Out:
# watermelon
# green

# %%
class Instructor:
     
     def __init__(self, name, technology, experience, feedback):
          self.name = name 
          self.__technology = technology
          self.__experience = experience
          self.__feedback = feedback
          
     def check_eligibility(self):
          if self.__experience > 3 and self.__feedback >= 4.5:
               return True
          elif self.__experience <= 3 and self.__feedback >= 4:
               return True
          else:
               return False
          
     def allocate__course(self, tech):
          is_eligible = self.check_eligibility()
          
          if is_eligible:
               if tech in self.__technology:
                    return 'Padha sakta hai'
               else:
                    return 'Ye to usko aata hi nahi hai'
          else :
               return 'acha nahi padhata hai'
ins = Instructor('Maruf', ['Data Science', 'Web Development'], 5,4.9)
ins.allocate__course('Data Science')
# Out:
# 'Padha sakta hai'
